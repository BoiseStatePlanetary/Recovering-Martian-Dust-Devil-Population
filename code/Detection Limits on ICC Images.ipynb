# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from statsmodels.robust import mad

# %%
image_file = "../figures/C000M0065_602302474EJP_F0000_0461M2_just_sky.JPG"

img = Image.open(image_file)
np_img = np.array(img)
  
plt.imshow(img)

# %%
ind = np_img < 200
print(np.max(np_img[ind]), np.min(np_img[ind]))
# Out:
# 199 36
